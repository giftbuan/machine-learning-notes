# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv('2025-05-31-data.csv')
view_count = df['view_count']
Likes = df['likes']
ratio = df['ratio']

plt.style.use('seaborn-v0-8')
plt.xscale('log')
plt.yscale('log')
plt.scatter(view_count, Like, c=ratio,
    cmap='summer', edgecolors='black', linewidths=1, alpha=0.75)
cbar=plt.colorbar()
cbar,set_label('Ratio of Likes and Dislikes')
plt.xlabel('View Count')
plt.ylabel('Likes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:873, in _rc_params_in_file(fname, transform, fail_on_error)
#     872 rc_temp = {}
# --> 873 with _open_file_or_url(fname) as fd:
#     874     try:
#
# File C:\Program Files\Python39\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:850, in _open_file_or_url(fname)
#     849 fname = os.path.expanduser(fname)
# --> 850 with open(fname, encoding='utf-8') as f:
#     851     yield f
#
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# 1. Load data
df = pd.read_csv('2025-05-31-data.csv')

# 2. Match variables to the exact CSV headers seen in your first image
view_count = df['view_count'] # Match: view_count
Likes = df['likes']          # Match: likes (lowercase in your CSV)
ratio = df['ratio']          # Match: ratio

# 3. Set plot style (Using a standard style to avoid the FileNotFoundError)
plt.style.use('ggplot') 
plt.xscale('log')
plt.yscale('log')

# 4. Create scatter plot (Fixed 'Like' vs 'Likes' variable mismatch)
plt.scatter(view_count, Likes, c=ratio, cmap='summer', 
            edgecolors='black', linewidths=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Ratio of Likes and Dislikes')

plt.xlabel('View Count')
plt.ylabel('Likes')

plt.tight_layout()
plt.show()
